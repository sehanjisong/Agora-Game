# %% [markdown]
# <a href="https://colab.research.google.com/github/sehanjisong/Agora-Game/blob/main/260412.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=3
x+3
# Out:
# 6

# %%
x*10
# Out:
# 30
